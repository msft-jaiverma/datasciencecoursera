# %% [markdown]
# <a href="https://colab.research.google.com/github/msft-jaiverma/datasciencecoursera/blob/main/FinalModel1_CreditRiskModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Loading the libraries
import numpy as np
# numpy stands for numerical python
import pandas as pd
# pandas stands for panel data
import matplotlib.pyplot as plt
# Matlab plot library

# %%
# read the data file
data = pd.read_csv("Churn_Modelling.csv")
# Check is the data is properly loaded
data.head()
# Out:
#    RowNumber  CustomerId   Surname  ...  IsActiveMember EstimatedSalary Exited
# 0          1    15634602  Hargrave  ...               1       101348.88      1
# 1          2    15647311      Hill  ...               1       112542.58      0
# 2          3    15619304      Onio  ...               0       113931.57      1
# 3          4    15701354      Boni  ...               0        93826.63      0
# 4          5    15737888  Mitchell  ...               1        79084.10      0
#
# [5 rows x 14 columns]

# %%
X = data.iloc[:,3:13].values
X
# Separate X and y
y = data.iloc[:,13].values
y
# Out:
# array([1, 0, 1, ..., 1, 1, 0])

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder = LabelEncoder()
X[:,2] = labelencoder.fit_transform(X[:,2]) # Gender
X[:,1] = labelencoder.fit_transform(X[:,1]) # Geography
X
# Out:
# array([[619, 0, 0, ..., 1, 1, 101348.88],
#        [608, 2, 0, ..., 0, 1, 112542.58],
#        [502, 0, 0, ..., 1, 0, 113931.57],
#        ...,
#        [709, 0, 0, ..., 0, 1, 42085.58],
#        [772, 1, 1, ..., 1, 0, 92888.52],
#        [792, 0, 0, ..., 1, 0, 38190.78]], dtype=object)

# %%
# Get the library from sklearn.compose 
from sklearn.compose import ColumnTransformer
# OneHot Encoder has been applied to column 1
# I have given the ColumnTransformer function a name of my choice which is country
# The functionality has been passed onto the variable ct but still not applied on the data
ct = ColumnTransformer([("Country", OneHotEncoder(), [1])], remainder = 'passthrough')
# We shall now apply it on the data
X = ct.fit_transform(X)
X
# Out:
# array([[1.0, 0.0, 0.0, ..., 1, 1, 101348.88],
#        [0.0, 0.0, 1.0, ..., 0, 1, 112542.58],
#        [1.0, 0.0, 0.0, ..., 1, 0, 113931.57],
#        ...,
#        [1.0, 0.0, 0.0, ..., 0, 1, 42085.58],
#        [0.0, 1.0, 0.0, ..., 1, 0, 92888.52],
#        [1.0, 0.0, 0.0, ..., 1, 0, 38190.78]], dtype=object)

# %% [markdown]
# Convert the data into a dataframe for each of understanding. Replace the countries with X1, X2 and X3 the values we have after one-hot encoding. The countries have been replaced by X1, X2 and X3 which is a vector.
# Example: France is now 1,0,0
# Spain has been replaced by 0,0,1

# %%
# Call the pandas dataframe command to convert the data into a frame which can be used further
# Note you are converting data type from Numpy array to Pandas
X = pd.DataFrame(X,columns = ["X1", "X2", "X3", "Credit Score", "Gender", "Age","Tenure", "Balance", "NumofProducts", "HasCrCard", "IsActive Member", "Estimated Salary"])
X
# Out:
#      X1 X2 X3  ... HasCrCard IsActive Member Estimated Salary
# 0     1  0  0  ...         1               1           101349
# 1     0  0  1  ...         0               1           112543
# 2     1  0  0  ...         1               0           113932
# 3     1  0  0  ...         0               0          93826.6
# 4     0  0  1  ...         1               1          79084.1
# ...  .. .. ..  ...       ...             ...              ...
# 9995  1  0  0  ...         1               0          96270.6
# 9996  1  0  0  ...         1               1           101700
# 9997  1  0  0  ...         0               1          42085.6
# 9998  0  1  0  ...         1               0          92888.5
# 9999  1  0  0  ...         1               0          38190.8
#
# [10000 rows x 12 columns]

# %%
# From the datafram drop X1
# axis = 1 indicates where should Python look for the variable X1
# The answer is that it should look for X1 along the X-axis and hence axis is set to 1
# If looking along the Y-axis the axis should be set to 0
X = X.drop("X1", axis = 1)
X
# Out:
#      X2 X3 Credit Score  ... HasCrCard IsActive Member Estimated Salary
# 0     0  0          619  ...         1               1           101349
# 1     0  1          608  ...         0               1           112543
# 2     0  0          502  ...         1               0           113932
# 3     0  0          699  ...         0               0          93826.6
# 4     0  1          850  ...         1               1          79084.1
# ...  .. ..          ...  ...       ...             ...              ...
# 9995  0  0          771  ...         1               0          96270.6
# 9996  0  0          516  ...         1               1           101700
# 9997  0  0          709  ...         0               1          42085.6
# 9998  1  0          772  ...         1               0          92888.5
# 9999  0  0          792  ...         1               0          38190.8
#
# [10000 rows x 11 columns]

# %%
#Split the dataset into train and test set

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 0)

# %%
#Feature Scaling 
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

#Standarized the train data
X_train = sc.fit_transform(X_train)

#Transform the test data, we do not need to standarized it.
X_test = sc.transform(X_test)

# %%
#Import Libraries
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
#Initializing the Deep Learning Model
classifier = Sequential()

#Adding the input layer, input dimenssion = 11, first hidden layer has 6 units with random weight
classifier.add(Dense(units = 6, kernel_initializer= 'uniform', activation= 'relu', input_dim=11))

#Adding the 2nd hidden layer, 
classifier.add(Dense(units = 6, kernel_initializer= 'uniform', activation= 'relu'))

#Adding Output layer. Activation function is sigmoid as this is binary problem
classifier.add(Dense(units=1, kernel_initializer= 'uniform', activation= 'sigmoid'))

# %%
#Compiling DNN
classifier.compile(optimizer= 'adam', loss = 'binary_crossentropy', metrics= ['accuracy'])

#Fitting the DNN to the training set
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 800/800 [==============================] - 9s 2ms/step - loss: 0.5761 - accuracy: 0.7952
# Epoch 2/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4290 - accuracy: 0.7978
# Epoch 3/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4368 - accuracy: 0.7884
# Epoch 4/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4211 - accuracy: 0.7978
# Epoch 5/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4142 - accuracy: 0.8253
# Epoch 6/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4061 - accuracy: 0.8372
# Epoch 7/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4099 - accuracy: 0.8283
# Epoch 8/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4117 - accuracy: 0.8280
# Epoch 9/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3945 - accuracy: 0.8404
# Epoch 10/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4084 - accuracy: 0.8282
# Epoch 11/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4040 - accuracy: 0.8355
# Epoch 12/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4134 - accuracy: 0.8321
# Epoch 13/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4054 - accuracy: 0.8351
# Epoch 14/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4159 - accuracy: 0.8274
# Epoch 15/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4006 - accuracy: 0.8358
# Epoch 16/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3956 - accuracy: 0.8416
# Epoch 17/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4113 - accuracy: 0.8322
# Epoch 18/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4064 - accuracy: 0.8348
# Epoch 19/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4043 - accuracy: 0.8358
# Epoch 20/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4025 - accuracy: 0.8362
# Epoch 21/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3992 - accuracy: 0.8392
# Epoch 22/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4097 - accuracy: 0.8316
# Epoch 23/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4028 - accuracy: 0.8309
# Epoch 24/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4002 - accuracy: 0.8388
# Epoch 25/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4080 - accuracy: 0.8318
# Epoch 26/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3936 - accuracy: 0.8385
# Epoch 27/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4151 - accuracy: 0.8281
# Epoch 28/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4087 - accuracy: 0.8352
# Epoch 29/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3981 - accuracy: 0.8383
# Epoch 30/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3960 - accuracy: 0.8410
# Epoch 31/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4172 - accuracy: 0.8242
# Epoch 32/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4074 - accuracy: 0.8279
# Epoch 33/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4089 - accuracy: 0.8308
# Epoch 34/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3823 - accuracy: 0.8433
# Epoch 35/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4083 - accuracy: 0.8306
# Epoch 36/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4032 - accuracy: 0.8357
# Epoch 37/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3868 - accuracy: 0.8421
# Epoch 38/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4022 - accuracy: 0.8312
# Epoch 39/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4008 - accuracy: 0.8342
# Epoch 40/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3967 - accuracy: 0.8408
# Epoch 41/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4021 - accuracy: 0.8358
# Epoch 42/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3929 - accuracy: 0.8405
# Epoch 43/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4109 - accuracy: 0.8272
# Epoch 44/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4060 - accuracy: 0.8341
# Epoch 45/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4071 - accuracy: 0.8301
# Epoch 46/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4033 - accuracy: 0.8405
# Epoch 47/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3970 - accuracy: 0.8369
# Epoch 48/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4052 - accuracy: 0.8353
# Epoch 49/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4021 - accuracy: 0.8320
# Epoch 50/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3922 - accuracy: 0.8401
# Epoch 51/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4069 - accuracy: 0.8324
# Epoch 52/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3964 - accuracy: 0.8352
# Epoch 53/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3959 - accuracy: 0.8386
# Epoch 54/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4025 - accuracy: 0.8356
# Epoch 55/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3985 - accuracy: 0.8361
# Epoch 56/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3895 - accuracy: 0.8474
# Epoch 57/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4068 - accuracy: 0.8321
# Epoch 58/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4016 - accuracy: 0.8356
# Epoch 59/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3986 - accuracy: 0.8375
# Epoch 60/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4055 - accuracy: 0.8370
# Epoch 61/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4089 - accuracy: 0.8321
# Epoch 62/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3972 - accuracy: 0.8388
# Epoch 63/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4072 - accuracy: 0.8309
# Epoch 64/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3975 - accuracy: 0.8388
# Epoch 65/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4093 - accuracy: 0.8302
# Epoch 66/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3953 - accuracy: 0.8361
# Epoch 67/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4021 - accuracy: 0.8339
# Epoch 68/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4093 - accuracy: 0.8292
# Epoch 69/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3946 - accuracy: 0.8367
# Epoch 70/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3988 - accuracy: 0.8370
# Epoch 71/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4092 - accuracy: 0.8331
# Epoch 72/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3963 - accuracy: 0.8357
# Epoch 73/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4027 - accuracy: 0.8318
# Epoch 74/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3986 - accuracy: 0.8346
# Epoch 75/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3987 - accuracy: 0.8387
# Epoch 76/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3996 - accuracy: 0.8377
# Epoch 77/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3951 - accuracy: 0.8386
# Epoch 78/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4046 - accuracy: 0.8372
# Epoch 79/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3928 - accuracy: 0.8373
# Epoch 80/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4044 - accuracy: 0.8368
# Epoch 81/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3995 - accuracy: 0.8354
# Epoch 82/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3949 - accuracy: 0.8404
# Epoch 83/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3905 - accuracy: 0.8372
# Epoch 84/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3960 - accuracy: 0.8353
# Epoch 85/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3967 - accuracy: 0.8388
# Epoch 86/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3964 - accuracy: 0.8396
# Epoch 87/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3979 - accuracy: 0.8375
# Epoch 88/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3978 - accuracy: 0.8358
# Epoch 89/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4035 - accuracy: 0.8359
# Epoch 90/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3963 - accuracy: 0.8378
# Epoch 91/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3954 - accuracy: 0.8402
# Epoch 92/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4025 - accuracy: 0.8365
# Epoch 93/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3923 - accuracy: 0.8383
# Epoch 94/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4007 - accuracy: 0.8345
# Epoch 95/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4013 - accuracy: 0.8330
# Epoch 96/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4106 - accuracy: 0.8308
# Epoch 97/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3980 - accuracy: 0.8348
# Epoch 98/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3903 - accuracy: 0.8395
# Epoch 99/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3925 - accuracy: 0.8382
# Epoch 100/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4009 - accuracy: 0.8357

# %%
import seaborn as sns

#predicting the test set results
y_pred = classifier.predict(X_test)

#Taking 0.5 as cutoff value
y_pred = (y_pred > 0.5)

#Create Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot = True, fmt = '');

# %%
#Accuracy based on the diagonal 
(1525+159) / 2000
# Out:
# 0.842
