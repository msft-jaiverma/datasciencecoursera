# %% [markdown]
# <a href="https://colab.research.google.com/github/msft-jaiverma/datasciencecoursera/blob/main/jai_xp21017_endterm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Loading the libraries
import numpy as np
# numpy stands for numerical python
import pandas as pd
# pandas stands for panel data
import matplotlib.pyplot as plt
# Matlab plot library

# %%
# read the data file
data = pd.read_csv("Churn_Modelling.csv")
# Check is the data is properly loaded
data.head()
# Out:
#    RowNumber  CustomerId   Surname  ...  IsActiveMember EstimatedSalary Exited
# 0          1    15634602  Hargrave  ...               1       101348.88      1
# 1          2    15647311      Hill  ...               1       112542.58      0
# 2          3    15619304      Onio  ...               0       113931.57      1
# 3          4    15701354      Boni  ...               0        93826.63      0
# 4          5    15737888  Mitchell  ...               1        79084.10      0
#
# [5 rows x 14 columns]

# %%
X = data.iloc[:,3:13].values
X
# Separate X and y
y = data.iloc[:,13].values
y
# Out:
# array([1, 0, 1, ..., 1, 1, 0])

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder = LabelEncoder()
X[:,2] = labelencoder.fit_transform(X[:,2]) # Gender
X[:,1] = labelencoder.fit_transform(X[:,1]) # Geography
X
# Out:
# array([[619, 0, 0, ..., 1, 1, 101348.88],
#        [608, 2, 0, ..., 0, 1, 112542.58],
#        [502, 0, 0, ..., 1, 0, 113931.57],
#        ...,
#        [709, 0, 0, ..., 0, 1, 42085.58],
#        [772, 1, 1, ..., 1, 0, 92888.52],
#        [792, 0, 0, ..., 1, 0, 38190.78]], dtype=object)

# %%
# Get the library from sklearn.compose 
from sklearn.compose import ColumnTransformer
# OneHot Encoder has been applied to column 1
# I have given the ColumnTransformer function a name of my choice which is country
# The functionality has been passed onto the variable ct but still not applied on the data
ct = ColumnTransformer([("Country", OneHotEncoder(), [1])], remainder = 'passthrough')
# We shall now apply it on the data
X = ct.fit_transform(X)
X
# Out:
# array([[1.0, 0.0, 0.0, ..., 1, 1, 101348.88],
#        [0.0, 0.0, 1.0, ..., 0, 1, 112542.58],
#        [1.0, 0.0, 0.0, ..., 1, 0, 113931.57],
#        ...,
#        [1.0, 0.0, 0.0, ..., 0, 1, 42085.58],
#        [0.0, 1.0, 0.0, ..., 1, 0, 92888.52],
#        [1.0, 0.0, 0.0, ..., 1, 0, 38190.78]], dtype=object)

# %% [markdown]
# Convert the data into a dataframe for each of understanding. Replace the countries with X1, X2 and X3 the values we have after one-hot encoding. The countries have been replaced by X1, X2 and X3 which is a vector.
# Example: France is now 1,0,0
# Spain has been replaced by 0,0,1

# %%
# Call the pandas dataframe command to convert the data into a frame which can be used further
# Note you are converting data type from Numpy array to Pandas
X = pd.DataFrame(X,columns = ["X1", "X2", "X3", "Credit Score", "Gender", "Age","Tenure", "Balance", "NumofProducts", "HasCrCard", "IsActive Member", "Estimated Salary"])
X
# Out:
#      X1 X2 X3  ... HasCrCard IsActive Member Estimated Salary
# 0     1  0  0  ...         1               1           101349
# 1     0  0  1  ...         0               1           112543
# 2     1  0  0  ...         1               0           113932
# 3     1  0  0  ...         0               0          93826.6
# 4     0  0  1  ...         1               1          79084.1
# ...  .. .. ..  ...       ...             ...              ...
# 9995  1  0  0  ...         1               0          96270.6
# 9996  1  0  0  ...         1               1           101700
# 9997  1  0  0  ...         0               1          42085.6
# 9998  0  1  0  ...         1               0          92888.5
# 9999  1  0  0  ...         1               0          38190.8
#
# [10000 rows x 12 columns]

# %%
# From the datafram drop X1
# axis = 1 indicates where should Python look for the variable X1
# The answer is that it should look for X1 along the X-axis and hence axis is set to 1
# If looking along the Y-axis the axis should be set to 0
X = X.drop("X1", axis = 1)
X
# Out:
#      X2 X3 Credit Score  ... HasCrCard IsActive Member Estimated Salary
# 0     0  0          619  ...         1               1           101349
# 1     0  1          608  ...         0               1           112543
# 2     0  0          502  ...         1               0           113932
# 3     0  0          699  ...         0               0          93826.6
# 4     0  1          850  ...         1               1          79084.1
# ...  .. ..          ...  ...       ...             ...              ...
# 9995  0  0          771  ...         1               0          96270.6
# 9996  0  0          516  ...         1               1           101700
# 9997  0  0          709  ...         0               1          42085.6
# 9998  1  0          772  ...         1               0          92888.5
# 9999  0  0          792  ...         1               0          38190.8
#
# [10000 rows x 11 columns]

# %%
#Split the dataset into train and test set

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 0)

# %%
#Feature Scaling 
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

#Standarized the train data
X_train = sc.fit_transform(X_train)

#Transform the test data, we do not need to standarized it.
X_test = sc.transform(X_test)

# %%
#Import Libraries
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
#Initializing the Deep Learning Model
classifier = Sequential()

#Adding the input layer, input dimenssion = 11, first hidden layer has 6 units with random weight
classifier.add(Dense(units = 6, kernel_initializer= 'uniform', activation= 'relu', input_dim=11))

#Adding the 2nd hidden layer, 
classifier.add(Dense(units = 6, kernel_initializer= 'uniform', activation= 'relu'))

#Adding Output layer. Activation function is sigmoid as this is binary problem
classifier.add(Dense(units=1, kernel_initializer= 'uniform', activation= 'sigmoid'))

# %%
#Compiling DNN
classifier.compile(optimizer= 'adam', loss = 'binary_crossentropy', metrics= ['accuracy'])

#Fitting the DNN to the training set
classifier.fit(X_train, y_train, batch_size = 40, epochs = 200)
# Out:
# Epoch 1/200
# 200/200 [==============================] - 1s 2ms/step - loss: 0.3234 - accuracy: 0.8659
# Epoch 2/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3386 - accuracy: 0.8603
# Epoch 3/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3348 - accuracy: 0.8610
# Epoch 4/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3317 - accuracy: 0.8666
# Epoch 5/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3314 - accuracy: 0.8670
# Epoch 6/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3282 - accuracy: 0.8678
# Epoch 7/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3357 - accuracy: 0.8618
# Epoch 8/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3408 - accuracy: 0.8606
# Epoch 9/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3382 - accuracy: 0.8657
# Epoch 10/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3440 - accuracy: 0.8568
# Epoch 11/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3281 - accuracy: 0.8646
# Epoch 12/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3324 - accuracy: 0.8621
# Epoch 13/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3361 - accuracy: 0.8654
# Epoch 14/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3323 - accuracy: 0.8607
# Epoch 15/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3173 - accuracy: 0.8692
# Epoch 16/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3420 - accuracy: 0.8574
# Epoch 17/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3380 - accuracy: 0.8596
# Epoch 18/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3330 - accuracy: 0.8667
# Epoch 19/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3441 - accuracy: 0.8596
# Epoch 20/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3330 - accuracy: 0.8662
# Epoch 21/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3403 - accuracy: 0.8623
# Epoch 22/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3346 - accuracy: 0.8613
# Epoch 23/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3330 - accuracy: 0.8644
# Epoch 24/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3349 - accuracy: 0.8674
# Epoch 25/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3338 - accuracy: 0.8614
# Epoch 26/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3320 - accuracy: 0.8634
# Epoch 27/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3366 - accuracy: 0.8631
# Epoch 28/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3331 - accuracy: 0.8675
# Epoch 29/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3229 - accuracy: 0.8678
# Epoch 30/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3321 - accuracy: 0.8639
# Epoch 31/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3317 - accuracy: 0.8661
# Epoch 32/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3311 - accuracy: 0.8646
# Epoch 33/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3364 - accuracy: 0.8632
# Epoch 34/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3364 - accuracy: 0.8587
# Epoch 35/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3415 - accuracy: 0.8608
# Epoch 36/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3402 - accuracy: 0.8587
# Epoch 37/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3410 - accuracy: 0.8650
# Epoch 38/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3384 - accuracy: 0.8660
# Epoch 39/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3303 - accuracy: 0.8664
# Epoch 40/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3423 - accuracy: 0.8570
# Epoch 41/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3225 - accuracy: 0.8703
# Epoch 42/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3329 - accuracy: 0.8644
# Epoch 43/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3435 - accuracy: 0.8608
# Epoch 44/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3392 - accuracy: 0.8617
# Epoch 45/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3258 - accuracy: 0.8659
# Epoch 46/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3384 - accuracy: 0.8615
# Epoch 47/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3373 - accuracy: 0.8687
# Epoch 48/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3263 - accuracy: 0.8691
# Epoch 49/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3401 - accuracy: 0.8618
# Epoch 50/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3391 - accuracy: 0.8576
# Epoch 51/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3314 - accuracy: 0.8648
# Epoch 52/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3455 - accuracy: 0.8544
# Epoch 53/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3423 - accuracy: 0.8579
# Epoch 54/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3327 - accuracy: 0.8636
# Epoch 55/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3358 - accuracy: 0.8662
# Epoch 56/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3271 - accuracy: 0.8647
# Epoch 57/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3408 - accuracy: 0.8561
# Epoch 58/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3311 - accuracy: 0.8626
# Epoch 59/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3411 - accuracy: 0.8627
# Epoch 60/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3559 - accuracy: 0.8574
# Epoch 61/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3318 - accuracy: 0.8639
# Epoch 62/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3421 - accuracy: 0.8579
# Epoch 63/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3415 - accuracy: 0.8577
# Epoch 64/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3230 - accuracy: 0.8679
# Epoch 65/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3270 - accuracy: 0.8647
# Epoch 66/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3329 - accuracy: 0.8659
# Epoch 67/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3382 - accuracy: 0.8596
# Epoch 68/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3372 - accuracy: 0.8607
# Epoch 69/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3328 - accuracy: 0.8612
# Epoch 70/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3387 - accuracy: 0.8583
# Epoch 71/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3287 - accuracy: 0.8683
# Epoch 72/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3261 - accuracy: 0.8697
# Epoch 73/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3426 - accuracy: 0.8598
# Epoch 74/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3331 - accuracy: 0.8628
# Epoch 75/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3290 - accuracy: 0.8682
# Epoch 76/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3213 - accuracy: 0.8692
# Epoch 77/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3367 - accuracy: 0.8635
# Epoch 78/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3352 - accuracy: 0.8647
# Epoch 79/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3442 - accuracy: 0.8597
# Epoch 80/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3304 - accuracy: 0.8612
# Epoch 81/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3416 - accuracy: 0.8598
# Epoch 82/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3445 - accuracy: 0.8569
# Epoch 83/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3300 - accuracy: 0.8634
# Epoch 84/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3307 - accuracy: 0.8660
# Epoch 85/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3377 - accuracy: 0.8625
# Epoch 86/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3370 - accuracy: 0.8608
# Epoch 87/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3382 - accuracy: 0.8583
# Epoch 88/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3459 - accuracy: 0.8574
# Epoch 89/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3399 - accuracy: 0.8601
# Epoch 90/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3463 - accuracy: 0.8567
# Epoch 91/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3457 - accuracy: 0.8572
# Epoch 92/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3283 - accuracy: 0.8674
# Epoch 93/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3420 - accuracy: 0.8594
# Epoch 94/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3417 - accuracy: 0.8634
# Epoch 95/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3344 - accuracy: 0.8625
# Epoch 96/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3457 - accuracy: 0.8611
# Epoch 97/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3423 - accuracy: 0.8595
# Epoch 98/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3329 - accuracy: 0.8614
# Epoch 99/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3343 - accuracy: 0.8667
# Epoch 100/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3420 - accuracy: 0.8570
# Epoch 101/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3277 - accuracy: 0.8656
# Epoch 102/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3425 - accuracy: 0.8608
# Epoch 103/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3372 - accuracy: 0.8652
# Epoch 104/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3331 - accuracy: 0.8606
# Epoch 105/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3299 - accuracy: 0.8653
# Epoch 106/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3375 - accuracy: 0.8621
# Epoch 107/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3437 - accuracy: 0.8573
# Epoch 108/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3360 - accuracy: 0.8635
# Epoch 109/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3234 - accuracy: 0.8668
# Epoch 110/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3304 - accuracy: 0.8645
# Epoch 111/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3428 - accuracy: 0.8618
# Epoch 112/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3359 - accuracy: 0.8591
# Epoch 113/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3494 - accuracy: 0.8565
# Epoch 114/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3414 - accuracy: 0.8622
# Epoch 115/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3338 - accuracy: 0.8645
# Epoch 116/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3323 - accuracy: 0.8615
# Epoch 117/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3340 - accuracy: 0.8642
# Epoch 118/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3269 - accuracy: 0.8674
# Epoch 119/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3329 - accuracy: 0.8654
# Epoch 120/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3378 - accuracy: 0.8609
# Epoch 121/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3321 - accuracy: 0.8633
# Epoch 122/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3372 - accuracy: 0.8627
# Epoch 123/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3384 - accuracy: 0.8587
# Epoch 124/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3404 - accuracy: 0.8596
# Epoch 125/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3378 - accuracy: 0.8652
# Epoch 126/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3271 - accuracy: 0.8632
# Epoch 127/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3476 - accuracy: 0.8556
# Epoch 128/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3318 - accuracy: 0.8615
# Epoch 129/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3327 - accuracy: 0.8654
# Epoch 130/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3334 - accuracy: 0.8628
# Epoch 131/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3450 - accuracy: 0.8598
# Epoch 132/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3343 - accuracy: 0.8589
# Epoch 133/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3401 - accuracy: 0.8545
# Epoch 134/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3274 - accuracy: 0.8653
# Epoch 135/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3295 - accuracy: 0.8664
# Epoch 136/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3314 - accuracy: 0.8572
# Epoch 137/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3331 - accuracy: 0.8651
# Epoch 138/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3462 - accuracy: 0.8569
# Epoch 139/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3313 - accuracy: 0.8657
# Epoch 140/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3267 - accuracy: 0.8664
# Epoch 141/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3373 - accuracy: 0.8628
# Epoch 142/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3300 - accuracy: 0.8671
# Epoch 143/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3209 - accuracy: 0.8677
# Epoch 144/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3240 - accuracy: 0.8687
# Epoch 145/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3315 - accuracy: 0.8662
# Epoch 146/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3287 - accuracy: 0.8626
# Epoch 147/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3425 - accuracy: 0.8587
# Epoch 148/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3471 - accuracy: 0.8553
# Epoch 149/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3331 - accuracy: 0.8645
# Epoch 150/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3291 - accuracy: 0.8640
# Epoch 151/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3321 - accuracy: 0.8653
# Epoch 152/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3375 - accuracy: 0.8671
# Epoch 153/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3352 - accuracy: 0.8623
# Epoch 154/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3352 - accuracy: 0.8645
# Epoch 155/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3392 - accuracy: 0.8606
# Epoch 156/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3373 - accuracy: 0.8654
# Epoch 157/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3241 - accuracy: 0.8673
# Epoch 158/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3270 - accuracy: 0.8676
# Epoch 159/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3202 - accuracy: 0.8732
# Epoch 160/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3337 - accuracy: 0.8629
# Epoch 161/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3454 - accuracy: 0.8538
# Epoch 162/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3359 - accuracy: 0.8610
# Epoch 163/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3293 - accuracy: 0.8696
# Epoch 164/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3299 - accuracy: 0.8635
# Epoch 165/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3369 - accuracy: 0.8603
# Epoch 166/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3304 - accuracy: 0.8683
# Epoch 167/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3333 - accuracy: 0.8628
# Epoch 168/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3467 - accuracy: 0.8606
# Epoch 169/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3321 - accuracy: 0.8605
# Epoch 170/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3313 - accuracy: 0.8648
# Epoch 171/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3385 - accuracy: 0.8594
# Epoch 172/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3252 - accuracy: 0.8648
# Epoch 173/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3387 - accuracy: 0.8595
# Epoch 174/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3456 - accuracy: 0.8610
# Epoch 175/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3333 - accuracy: 0.8637
# Epoch 176/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3285 - accuracy: 0.8625
# Epoch 177/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3419 - accuracy: 0.8568
# Epoch 178/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3301 - accuracy: 0.8596
# Epoch 179/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3413 - accuracy: 0.8622
# Epoch 180/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3488 - accuracy: 0.8577
# Epoch 181/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3282 - accuracy: 0.8671
# Epoch 182/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3351 - accuracy: 0.8604
# Epoch 183/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3435 - accuracy: 0.8583
# Epoch 184/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3318 - accuracy: 0.8657
# Epoch 185/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3204 - accuracy: 0.8700
# Epoch 186/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3296 - accuracy: 0.8623
# Epoch 187/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3382 - accuracy: 0.8617
# Epoch 188/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3379 - accuracy: 0.8614
# Epoch 189/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3426 - accuracy: 0.8572
# Epoch 190/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3440 - accuracy: 0.8579
# Epoch 191/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3426 - accuracy: 0.8559
# Epoch 192/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3274 - accuracy: 0.8700
# Epoch 193/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3384 - accuracy: 0.8616
# Epoch 194/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3268 - accuracy: 0.8678
# Epoch 195/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3296 - accuracy: 0.8673
# Epoch 196/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3286 - accuracy: 0.8688
# Epoch 197/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3450 - accuracy: 0.8557
# Epoch 198/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3404 - accuracy: 0.8607
# Epoch 199/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3339 - accuracy: 0.8642
# Epoch 200/200
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3250 - accuracy: 0.8658

# %%
import seaborn as sns

#predicting the test set results
y_pred = classifier.predict(X_test)

#Taking 0.5 as cutoff value
y_pred = (y_pred > 0.5)

#Create Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot = True, fmt = '');

# %%
#Accuracy based on the diagonal 
(1518+207) / 2000
# Out:
# 0.8625
